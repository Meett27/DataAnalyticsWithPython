# %% [markdown]
# # Lab-4

# %% [markdown]
# # Data visualization part-2  Seaborn Exercises

# %% [markdown]
# ## Import Numpy, Panda and Matplotlib library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
iris = pd.read_csv('/content/drive/MyDrive/Data Analytics/Week-5/iris.csv')

iris.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
# print top 5 row of the dataset
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ## Exercises 1

# %%
# Write the code to show the graph below.
sns.distplot(iris['sepal.width'],kde=True,bins=10)
# Out:
# <ipython-input-10-59de99a9dac9>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['sepal.width'],kde=True,bins=10)
# <Axes: xlabel='sepal.width', ylabel='Density'>

# %% [markdown]
# ## Exercises 2

# %%
# Write the code to show the graph below.
sns.pairplot(iris)

# %% [markdown]
# ## Exercises 3

# %%
# Write the code to show the graph below.
sns.boxplot(data=iris,palette='rainbow',orient='h')
# Out:
# <Axes: >

# %% [markdown]
# ## Exercises 4

# %%
# Write the code to show the graph below.
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %% [markdown]
# ## Exercises 5

# %%
# Write the code to show the graph below.
iris_subset = iris[['sepal.length', 'sepal.width', 'petal.length', 'petal.width']]
sns.pairplot(iris_subset)
plt.show()

# %% [markdown]
# ## Exercises 6

# %% [markdown]
# Create a Categorical Plot for the column Sex of the Titanic dataset.

# %%
titanic = pd.read_csv('/content/drive/MyDrive/Data Analytics/Week-4/Titanic_1.csv')
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# Please save as Pdf and submit in Blackboard Lab4.

# %%
sns.barplot(x='Sex',y='PassengerId',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='PassengerId'>

# %%
sns.boxplot(x="Sex", y="Age", data=titanic,palette='rainbow')
# Out:
# <ipython-input-17-cd3070c1835e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Sex", y="Age", data=titanic,palette='rainbow')
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(data=titanic,palette='rainbow',orient='h')
# Out:
# <Axes: >
